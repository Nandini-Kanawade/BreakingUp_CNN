# %%
#imports

import os
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.callbacks import Callback

# %%
#Loading the dataset
mnist = keras.datasets.mnist
(x_full, y_full), (x_test_full, y_test_full) = mnist.load_data()

# %%
x_train_1 = x_full[y_full == 1][:]
x_train_7 = x_full[y_full == 7][:]
x_test_1 = x_test_full[y_test_full == 1][:]
x_test_7 = x_test_full[y_test_full == 7][:]

# %%
print(len(x_train_1),len(x_train_7))
print(len(x_test_1),len(x_test_7))
# Out:
# 6742 6265
# 1135 1028

# %%
# Training Data
'''
TRAINING DATA
5851 - 1
5851 - 7 
    [5851 * 8]
'''

x_train_0 = x_full[y_full == 1][:5851]
y_train_0 = np.ones((5851,))
print("shape_training_0 =>")
print("\t",x_train_0.shape)
print("\t",y_train_0.shape)

x_train_8 = x_full[y_full == 7][:5851]
y_train_8 = np.zeros((5851,))
print("shape_training_8 =>")
print("\t",x_train_8.shape)
print("\t",y_train_8.shape)

x_train = np.concatenate([x_train_0, x_train_8], axis=0)
y_train = np.concatenate([y_train_0, y_train_8], axis=0)
x_train, y_train = shuffle(x_train, y_train, random_state=42)
print("shape_training_complete =>")
print("\t",x_train.shape)
print("\t",y_train.shape)
# Out:
# shape_training_0 =>
# 	 (5851, 28, 28)
# 	 (5851,)
# shape_training_8 =>
# 	 (5851, 28, 28)
# 	 (5851,)
# shape_training_complete =>
# 	 (11702, 28, 28)
# 	 (11702,)

# %%
# Testing Data
'''
TESTING DATA
974 - 1
974 - 7 
    [974 * 8]
'''

x_test_0 = x_test_full[y_test_full == 1][:974]
y_test_0 = np.ones((974,))
print("shape_testing_0 =>")
print("\t",x_test_0.shape)
print("\t",y_test_0.shape)

x_test_8 = x_test_full[y_test_full == 7][:974]
y_test_8 = np.zeros((974,))
print("shape_testing_8 =>")
print("\t",x_test_8.shape)
print("\t",y_test_8.shape)

x_test = np.concatenate([x_test_0, x_test_8], axis=0)
y_test = np.concatenate([y_test_0, y_test_8], axis=0)
x_test, y_test = shuffle(x_test, y_test, random_state=42)
print("shape_testing_complete =>")
print("\t",x_test.shape)
print("\t",y_test.shape)
# Out:
# shape_testing_0 =>
# 	 (974, 28, 28)
# 	 (974,)
# shape_testing_8 =>
# 	 (974, 28, 28)
# 	 (974,)
# shape_testing_complete =>
# 	 (1948, 28, 28)
# 	 (1948,)

# %%
model_dense = models.Sequential()
model_dense.add(layers.Flatten(input_shape=(28, 28, 1)))
model_dense.add(layers.Dense(1, activation='sigmoid'))  
model_dense.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model_dense.summary()


model_convDense = models.Sequential()
model_convDense.add(layers.Conv2D(1, (3, 3), padding='valid', input_shape=(28, 28, 1)))
model_convDense.add(layers.Flatten())
model_convDense.add(layers.Dense(1, activation='sigmoid'))  
model_convDense.compile(
    optimizer='adam',               
    loss='binary_crossentropy',    
    metrics=['accuracy']           
)
model_convDense.summary()
# Out:
# c:\Users\nandi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           785 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)
# c:\Users\nandi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 1)      │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 676)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 687 (2.68 KB)
#  Trainable params: 687 (2.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def load_model_weights(model, weight_dir):
    
    for layer_num, layer in enumerate(model.layers):
        file_path = os.path.join(weight_dir, f"layer_number_{layer_num}.npz")
        if os.path.exists(file_path):
            loaded = np.load(file_path)
            weights = [loaded[key] for key in loaded]
            if layer.weights: 
                layer.set_weights(weights)
                print(f"Loaded weights for layer {layer_num} from {file_path}")
            else:
                print(f"Layer {layer_num} has no weights.")
        else:
            print(f"No weights found for layer {layer_num}.")

load_model_weights(model_dense, "../InitWeightsDense")
load_model_weights(model_convDense, "../InitWeightsConvDense")
# Out:
# No weights found for layer 0.
# Loaded weights for layer 1 from ../InitWeightsDense\layer_number_1.npz
# Loaded weights for layer 0 from ../InitWeightsConvDense\layer_number_0.npz
# No weights found for layer 1.
# Loaded weights for layer 2 from ../InitWeightsConvDense\layer_number_2.npz

# %%
class SaveWeightsCallback(callbacks.Callback):
    def __init__(self, save_dir):
        super(SaveWeightsCallback, self).__init__()
        self.save_dir = save_dir

    def on_epoch_end(self, epoch, logs=None):
        epoch_dir = os.path.join(self.save_dir, f"AfterEpoch{epoch + 1}")
        if not os.path.exists(epoch_dir):
            os.makedirs(epoch_dir)
        
        for layer_num, layer in enumerate(self.model.layers):
            if layer.weights:  # Only save weights for layers that have weights
                file_path = os.path.join(epoch_dir, f"Layer_{layer_num}.npz")
                weights = layer.get_weights()
                np.savez(file_path, *weights)
                print(f"Saved weights for layer {layer_num} to {file_path}")

# %%
save_dir_dense = "results/One_WeightsDense"
save_dir_convDense = "results/One_WeightsConvDense"
save_weights_callback_dense = SaveWeightsCallback(save_dir_dense)
save_weights_callback_convDense = SaveWeightsCallback(save_dir_convDense)

# %%
history_dense = model_dense.fit(
    x_train, y_train,
    epochs=15,  
    callbacks=[save_weights_callback_dense]
)
history_convDense = model_convDense.fit(
    x_train, y_train,
    epochs=15,  
    callbacks=[save_weights_callback_convDense]
)
# Out:
# Epoch 1/15
# 324/366 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.9430 - loss: 2.1933Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch1\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9469 - loss: 2.0343
# Epoch 2/15
# 353/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.2120Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch2\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.2117
# Epoch 3/15
# 352/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.1215Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch3\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9930 - loss: 0.1220
# Epoch 4/15
# 302/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9948 - loss: 0.1270Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch4\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9949 - loss: 0.1247
# Epoch 5/15
# 365/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0739Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch5\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9964 - loss: 0.0740
# Epoch 6/15
# 348/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0422Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch6\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0438
# Epoch 7/15
# 348/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0414Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch7\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0427
# Epoch 8/15
# 341/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0537Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch8\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0550
# Epoch 9/15
# 337/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0728Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch9\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0711
# Epoch 10/15
# 350/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9977 - loss: 0.0310Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch10\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9977 - loss: 0.0314
# Epoch 11/15
# 335/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0662Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch11\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0659
# Epoch 12/15
# 354/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0468Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch12\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0471
# Epoch 13/15
# 323/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9980 - loss: 0.0354Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch13\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9979 - loss: 0.0369
# Epoch 14/15
# 363/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9966 - loss: 0.0464Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch14\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9966 - loss: 0.0465
# Epoch 15/15
# 341/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0636Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch15\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9969 - loss: 0.0628
# Epoch 1/15
# 330/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9595 - loss: 1.8648Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch1\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch1\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9616 - loss: 1.7559
# Epoch 2/15
# 359/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.2006Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch2\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch2\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9935 - loss: 0.2000
# Epoch 3/15
# 362/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9930 - loss: 0.1088Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch3\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch3\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9930 - loss: 0.1088
# Epoch 4/15
# 346/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9959 - loss: 0.0570Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch4\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch4\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0587
# Epoch 5/15
# 364/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0951Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch5\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch5\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9939 - loss: 0.0948
# Epoch 6/15
# 339/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9951 - loss: 0.0548Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch6\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch6\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9951 - loss: 0.0547
# Epoch 7/15
# 352/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.0268Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch7\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch7\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9966 - loss: 0.0269
# Epoch 8/15
# 365/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0255Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch8\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch8\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9967 - loss: 0.0256
# Epoch 9/15
# 338/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0241Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch9\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch9\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9975 - loss: 0.0244
# Epoch 10/15
# 361/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9967 - loss: 0.0313Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch10\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch10\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9967 - loss: 0.0312
# Epoch 11/15
# 360/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9972 - loss: 0.0186Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch11\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch11\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9972 - loss: 0.0187
# Epoch 12/15
# 358/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9973 - loss: 0.0162Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch12\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch12\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9973 - loss: 0.0163
# Epoch 13/15
# 349/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0222Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch13\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch13\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0219
# Epoch 14/15
# 361/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0145Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch14\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch14\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9975 - loss: 0.0145
# Epoch 15/15
# 318/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0212Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch15\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch15\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9974 - loss: 0.0199

# %%
test_loss, test_acc = model_dense.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

test_loss, test_acc = model_convDense.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9947 - loss: 0.2607
# Test accuracy: 0.9933264851570129
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.1589
# Test accuracy: 0.994353175163269

# %%
dense_history_dict = history_dense.history
conv_dense_history_dict = history_convDense.history
dense_accuracy = dense_history_dict['accuracy']
conv_dense_accuracy = conv_dense_history_dict['accuracy']
dense_loss = dense_history_dict['loss']
conv_dense_loss = conv_dense_history_dict['loss']

epochs = range(1, len(dense_accuracy) + 1)

# accuracy
plt.figure(figsize=(8, 6))  
plt.plot(epochs, dense_accuracy, 'bo-', label='Dense Accuracy', markersize=8)
plt.plot(epochs, conv_dense_accuracy, 'go-', label='ConvDense Accuracy', markersize=8)
plt.title('Accuracy over Epochs', fontsize=18)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(ticks=epochs)
plt.savefig("results/one_accuracy_plot.png", bbox_inches='tight', dpi=1000 )
plt.show()
plt.close()

# loss
plt.figure(figsize=(8, 6))  # Larger figure for better clarity
plt.plot(epochs, dense_loss, 'bo-', label='Dense Loss', markersize=8)
plt.plot(epochs, conv_dense_loss, 'go-', label='ConvDense Loss', markersize=8)
plt.title('Loss over Epochs', fontsize=18)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(ticks=epochs)
plt.savefig("results/one_loss_plot.png", bbox_inches='tight', dpi=1000)
plt.show()
plt.close()

# %%
def plot_kernel(kernel, title):
    plt.figure(figsize=(6, 6))
    # Extract the 2D slice of the kernel weights
    kernel_2d = kernel.reshape(3,3) # Assumes single channel filter
    sns.heatmap(kernel_2d, annot=True, cmap="coolwarm", cbar=True)
    plt.title(title)
    plt.show()
final_kernel = model_convDense.layers[0].get_weights()[0]
plot_kernel(final_kernel, 'Trained Weights of Kernel One')

# %%
#imports

import os
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.callbacks import Callback

# %%
#Loading the dataset
mnist = keras.datasets.mnist
(x_full, y_full), (x_test_full, y_test_full) = mnist.load_data()

# %%
x_train_1 = x_full[y_full == 1][:]
x_train_7 = x_full[y_full == 7][:]
x_test_1 = x_test_full[y_test_full == 1][:]
x_test_7 = x_test_full[y_test_full == 7][:]

# %%
print(len(x_train_1),len(x_train_7))
print(len(x_test_1),len(x_test_7))
# Out:
# 6742 6265
# 1135 1028

# %%
# Training Data
'''
TRAINING DATA
5848 - 0
5848 - 8, 6, 3, 2 
    [1462 * 4]
'''

x_train_0 = x_full[y_full == 0][:5848]
y_train_0 = np.ones((5848,))
print("shape_training_0 =>")
print("\t",x_train_0.shape)
print("\t",y_train_0.shape)

num=[2,3,6,8]
x_train_others = []
y_train_others = []
for digit in num:
    x_digit = x_full[y_full == digit][:1462]
    y_digit = np.zeros((1462,))  
    x_train_others.append(x_digit)
    y_train_others.append(y_digit)
print("lenght_training_other =>")
print("\t",len(x_train_others),len(y_train_others))

x_train_others = np.concatenate(x_train_others, axis=0)
y_train_others = np.concatenate(y_train_others, axis=0)
print("shape_training_other =>")
print("\t",x_train_others.shape)
print("\t",y_train_others.shape)

x_train = np.concatenate([x_train_0, x_train_others], axis=0)
y_train = np.concatenate([y_train_0, y_train_others], axis=0)
x_train, y_train = shuffle(x_train, y_train, random_state=42)
print("shape_training_complete =>")
print("\t",x_train.shape)
print("\t",y_train.shape)
# Out:
# shape_training_0 =>
# 	 (5848, 28, 28)
# 	 (5848,)
# lenght_training_other =>
# 	 4 4
# shape_training_other =>
# 	 (5848, 28, 28)
# 	 (5848,)
# shape_training_complete =>
# 	 (11696, 28, 28)
# 	 (11696,)

# %%
# Testing Data
'''
TESTING DATA
972 - 0
972 - 2, 3, 6, 8
    [243 * 4]
'''

x_test_0 = x_test_full[y_test_full == 0][:972]
y_test_0 = np.ones((972,))
print("shape_training_0 =>")
print("\t",x_test_0.shape)
print("\t",y_test_0.shape)

num=[2,3,6,8]
x_test_others = []
y_test_others = []
for digit in num:
    x_digit = x_test_full[y_test_full == digit][:243]
    y_digit = np.zeros((243,))  
    x_test_others.append(x_digit)
    y_test_others.append(y_digit)
print("lenght_training_other =>")
print("\t",len(x_test_others),len(y_test_others))

x_test_others = np.concatenate(x_test_others, axis=0)
y_test_others = np.concatenate(y_test_others, axis=0)
print("shape_training_other =>")
print("\t",x_test_others.shape)
print("\t",y_test_others.shape)

x_test = np.concatenate([x_test_0, x_test_others], axis=0)
y_test = np.concatenate([y_test_0, y_test_others], axis=0)
x_test, y_test = shuffle(x_test, y_test, random_state=42)
print("shape_training_complete =>")
print("\t",x_test.shape)
print("\t",y_test.shape)
# Out:
# shape_training_0 =>
# 	 (972, 28, 28)
# 	 (972,)
# lenght_training_other =>
# 	 4 4
# shape_training_other =>
# 	 (972, 28, 28)
# 	 (972,)
# shape_training_complete =>
# 	 (1944, 28, 28)
# 	 (1944,)

# %%
model_dense = models.Sequential()
model_dense.add(layers.Flatten(input_shape=(28, 28, 1)))
model_dense.add(layers.Dense(1, activation='sigmoid'))  
model_dense.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model_dense.summary()


model_convDense = models.Sequential()
model_convDense.add(layers.Conv2D(1, (3, 3), padding='valid', input_shape=(28, 28, 1)))
model_convDense.add(layers.Flatten())
model_convDense.add(layers.Dense(1, activation='sigmoid'))  
model_convDense.compile(
    optimizer='adam',               
    loss='binary_crossentropy',    
    metrics=['accuracy']           
)
model_convDense.summary()
# Out:
# c:\Users\nandi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           785 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)
# c:\Users\nandi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 26, 26, 1)      │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 676)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 687 (2.68 KB)
#  Trainable params: 687 (2.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def load_model_weights(model, weight_dir):
    
    for layer_num, layer in enumerate(model.layers):
        file_path = os.path.join(weight_dir, f"layer_number_{layer_num}.npz")
        if os.path.exists(file_path):
            loaded = np.load(file_path)
            weights = [loaded[key] for key in loaded]
            if layer.weights: 
                layer.set_weights(weights)
                print(f"Loaded weights for layer {layer_num} from {file_path}")
            else:
                print(f"Layer {layer_num} has no weights.")
        else:
            print(f"No weights found for layer {layer_num}.")

load_model_weights(model_dense, "../InitWeightsDense")
load_model_weights(model_convDense, "../InitWeightsConvDense")
# Out:
# No weights found for layer 0.
# Loaded weights for layer 1 from ../InitWeightsDense\layer_number_1.npz
# Loaded weights for layer 0 from ../InitWeightsConvDense\layer_number_0.npz
# No weights found for layer 1.
# Loaded weights for layer 2 from ../InitWeightsConvDense\layer_number_2.npz

# %%
class SaveWeightsCallback(callbacks.Callback):
    def __init__(self, save_dir):
        super(SaveWeightsCallback, self).__init__()
        self.save_dir = save_dir

    def on_epoch_end(self, epoch, logs=None):
        epoch_dir = os.path.join(self.save_dir, f"AfterEpoch{epoch + 1}")
        if not os.path.exists(epoch_dir):
            os.makedirs(epoch_dir)
        
        for layer_num, layer in enumerate(self.model.layers):
            if layer.weights:  # Only save weights for layers that have weights
                file_path = os.path.join(epoch_dir, f"Layer_{layer_num}.npz")
                weights = layer.get_weights()
                np.savez(file_path, *weights)
                print(f"Saved weights for layer {layer_num} to {file_path}")

# %%
save_dir_dense = "results/One_WeightsDense"
save_dir_convDense = "results/One_WeightsConvDense"
save_weights_callback_dense = SaveWeightsCallback(save_dir_dense)
save_weights_callback_convDense = SaveWeightsCallback(save_dir_convDense)

# %%
history_dense = model_dense.fit(
    x_train, y_train,
    epochs=15,  
    callbacks=[save_weights_callback_dense]
)
history_convDense = model_convDense.fit(
    x_train, y_train,
    epochs=15,  
    callbacks=[save_weights_callback_convDense]
)
# Out:
# Epoch 1/15
# 316/366 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.8307 - loss: 12.9342Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch1\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - accuracy: 0.8438 - loss: 11.7348
# Epoch 2/15
# 362/366 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9719 - loss: 0.9712Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch2\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9719 - loss: 0.9712
# Epoch 3/15
# 357/366 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9808 - loss: 0.6852Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch3\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9807 - loss: 0.6875
# Epoch 4/15
# 340/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9791 - loss: 0.6557Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch4\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9790 - loss: 0.6589
# Epoch 5/15
# 361/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9775 - loss: 0.7261Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch5\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9775 - loss: 0.7253
# Epoch 6/15
# 336/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.7192Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch6\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9782 - loss: 0.7183
# Epoch 7/15
# 349/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9785 - loss: 0.6684Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch7\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9786 - loss: 0.6650
# Epoch 8/15
# 359/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9804 - loss: 0.5468Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch8\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9804 - loss: 0.5481
# Epoch 9/15
# 344/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.7424Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch9\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9772 - loss: 0.7355
# Epoch 10/15
# 351/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.6126Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch10\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9808 - loss: 0.6098
# Epoch 11/15
# 310/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9763 - loss: 0.6952Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch11\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9767 - loss: 0.6851
# Epoch 12/15
# 336/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9833 - loss: 0.5431Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch12\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9831 - loss: 0.5480
# Epoch 13/15
# 331/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9821 - loss: 0.5533Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch13\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9818 - loss: 0.5576
# Epoch 14/15
# 364/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9799 - loss: 0.5157Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch14\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9799 - loss: 0.5160
# Epoch 15/15
# 362/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9852 - loss: 0.4517Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch15\Layer_1.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9852 - loss: 0.4516
# Epoch 1/15
# 356/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8931 - loss: 6.2453Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch1\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch1\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8946 - loss: 6.1376
# Epoch 2/15
# 365/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9701 - loss: 0.8488Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch2\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch2\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9701 - loss: 0.8484
# Epoch 3/15
# 358/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9711 - loss: 0.6019Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch3\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch3\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9712 - loss: 0.5999
# Epoch 4/15
# 355/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9791 - loss: 0.3577Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch4\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch4\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9791 - loss: 0.3579
# Epoch 5/15
# 354/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9760 - loss: 0.3001Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch5\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch5\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.2996
# Epoch 6/15
# 355/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9808 - loss: 0.2297Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch6\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch6\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9808 - loss: 0.2291
# Epoch 7/15
# 349/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.1681Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch7\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch7\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9805 - loss: 0.1687
# Epoch 8/15
# 337/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.1431Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch8\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch8\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9818 - loss: 0.1427
# Epoch 9/15
# 362/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.1172Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch9\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch9\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9810 - loss: 0.1172
# Epoch 10/15
# 324/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.0834Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch10\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch10\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9818 - loss: 0.0851
# Epoch 11/15
# 354/366 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9823 - loss: 0.0798Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch11\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch11\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9823 - loss: 0.0799
# Epoch 12/15
# 347/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0667Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch12\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch12\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9844 - loss: 0.0670
# Epoch 13/15
# 358/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9836 - loss: 0.0593Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch13\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch13\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9836 - loss: 0.0594
# Epoch 14/15
# 338/366 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.0483Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch14\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch14\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9868 - loss: 0.0490
# Epoch 15/15
# 365/366 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9854 - loss: 0.0535Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch15\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch15\Layer_2.npz
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9854 - loss: 0.0535

# %%
test_loss, test_acc = model_dense.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

test_loss, test_acc = model_convDense.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - accuracy: 0.9719 - loss: 0.7878
# Test accuracy: 0.9753086566925049
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.9807 - loss: 0.0826
# Test accuracy: 0.9789094924926758

# %%
dense_history_dict = history_dense.history
conv_dense_history_dict = history_convDense.history
dense_accuracy = dense_history_dict['accuracy']
conv_dense_accuracy = conv_dense_history_dict['accuracy']
dense_loss = dense_history_dict['loss']
conv_dense_loss = conv_dense_history_dict['loss']

epochs = range(1, len(dense_accuracy) + 1)

# accuracy
plt.figure(figsize=(8, 6))  
plt.plot(epochs, dense_accuracy, 'bo-', label='Dense Accuracy', markersize=8)
plt.plot(epochs, conv_dense_accuracy, 'go-', label='ConvDense Accuracy', markersize=8)
plt.title('Accuracy over Epochs', fontsize=18)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(ticks=epochs)
plt.savefig("results/one_accuracy_plot.png", bbox_inches='tight', dpi=1000 )
plt.show()
plt.close()

# loss
plt.figure(figsize=(8, 6))  # Larger figure for better clarity
plt.plot(epochs, dense_loss, 'bo-', label='Dense Loss', markersize=8)
plt.plot(epochs, conv_dense_loss, 'go-', label='ConvDense Loss', markersize=8)
plt.title('Loss over Epochs', fontsize=18)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(ticks=epochs)
plt.savefig("results/one_loss_plot.png", bbox_inches='tight', dpi=1000)
plt.show()
plt.close()

# %%
def plot_kernel(kernel, title):
    plt.figure(figsize=(6, 6))
    # Extract the 2D slice of the kernel weights
    kernel_2d = kernel.reshape(3,3) # Assumes single channel filter
    sns.heatmap(kernel_2d, annot=True, cmap="coolwarm", cbar=True)
    plt.title(title)
    plt.show()
final_kernel = model_convDense.layers[0].get_weights()[0]
plot_kernel(final_kernel, 'Trained Weights of Kernel One')

# %%
#imports

import os
import numpy as np
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.callbacks import Callback

# %%
#Loading the dataset
mnist = keras.datasets.mnist
(x_full, y_full), (x_test_full, y_test_full) = mnist.load_data()

# %%
# Training Data
'''
TRAINING DATA
5400 - ones
5400 - other 
    [600 * 9 of 1/0 to 9]
'''

x_train_0 = x_full[y_full == 1][:5400]
y_train_0 = np.ones((5400,))
print("shape_training_0 =>")
print("\t",x_train_0.shape)
print("\t",y_train_0.shape)

x_train_others = []
y_train_others = []

x_digit = x_full[y_full == 0][:600]
y_digit = np.zeros((600,))  
x_train_others.append(x_digit)
y_train_others.append(y_digit)

for digit in range(2,10):
    x_digit = x_full[y_full == digit][:600]
    y_digit = np.zeros((600,))  
    x_train_others.append(x_digit)
    y_train_others.append(y_digit)
print("lenght_training_other =>")
print("\t",len(x_train_others),len(y_train_others))

x_train_others = np.concatenate(x_train_others, axis=0)
y_train_others = np.concatenate(y_train_others, axis=0)
print("shape_training_other =>")
print("\t",x_train_others.shape)
print("\t",y_train_others.shape)

x_train = np.concatenate([x_train_0, x_train_others], axis=0)
y_train = np.concatenate([y_train_0, y_train_others], axis=0)
x_train, y_train = shuffle(x_train, y_train, random_state=42)
print("shape_training_complete =>")
print("\t",x_train.shape)
print("\t",y_train.shape)
# Out:
# shape_training_0 =>
# 	 (5400, 28, 28)
# 	 (5400,)
# lenght_training_other =>
# 	 9 9
# shape_training_other =>
# 	 (5400, 28, 28)
# 	 (5400,)
# shape_training_complete =>
# 	 (10800, 28, 28)
# 	 (10800,)

# %%
# Testing Data
'''
TESTING DATA
810 - ones
810 - other 
    [90 * 9 of 1/0 to 9]
'''

x_test_0 = x_test_full[y_test_full == 1][:810]
y_test_0 = np.ones((810,))
print("shape_testing_0 =>")
print("\t",x_test_0.shape)
print("\t",y_test_0.shape)

x_test_others = []
y_test_others = []
x_digit = x_test_full[y_test_full == 0][:90]
y_digit = np.zeros((90,))  
x_test_others.append(x_digit)
y_test_others.append(y_digit)
for digit in range(2,10):
    x_digit = x_test_full[y_test_full == digit][:90]
    y_digit = np.zeros((90,))  
    x_test_others.append(x_digit)
    y_test_others.append(y_digit)
print("lenght_testing_other =>")
print("\t",len(x_test_others),len(y_test_others))

x_test_others = np.concatenate(x_test_others, axis=0)
y_test_others = np.concatenate(y_test_others, axis=0)
print("shape_testing_other =>")
print("\t",x_test_others.shape)
print("\t",y_test_others.shape)


x_test = np.concatenate([x_test_0, x_test_others], axis=0)
y_test = np.concatenate([y_test_0, y_test_others], axis=0)
x_test, y_test = shuffle(x_test, y_test, random_state=42)
print("shape_testing_complete =>")
print("\t",x_test.shape)
print("\t",y_test.shape)
# Out:
# shape_testing_0 =>
# 	 (810, 28, 28)
# 	 (810,)
# lenght_testing_other =>
# 	 9 9
# shape_testing_other =>
# 	 (810, 28, 28)
# 	 (810,)
# shape_testing_complete =>
# 	 (1620, 28, 28)
# 	 (1620,)

# %%
model_dense = models.Sequential()
model_dense.add(layers.Flatten(input_shape=(28, 28, 1)))
model_dense.add(layers.Dense(1, activation='sigmoid'))  
model_dense.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model_dense.summary()


model_convDense = models.Sequential()
model_convDense.add(layers.Conv2D(1, (3, 3), padding='valid', input_shape=(28, 28, 1)))
model_convDense.add(layers.Flatten())
model_convDense.add(layers.Dense(1, activation='sigmoid'))  
model_convDense.compile(
    optimizer='adam',               
    loss='binary_crossentropy',    
    metrics=['accuracy']           
)
model_convDense.summary()
# Out:
# c:\Users\nandi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           785 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)
# c:\Users\nandi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 26, 26, 1)      │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 676)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 687 (2.68 KB)
#  Trainable params: 687 (2.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def load_model_weights(model, weight_dir):
    
    for layer_num, layer in enumerate(model.layers):
        file_path = os.path.join(weight_dir, f"layer_number_{layer_num}.npz")
        if os.path.exists(file_path):
            loaded = np.load(file_path)
            weights = [loaded[key] for key in loaded]
            if layer.weights: 
                layer.set_weights(weights)
                print(f"Loaded weights for layer {layer_num} from {file_path}")
            else:
                print(f"Layer {layer_num} has no weights.")
        else:
            print(f"No weights found for layer {layer_num}.")

load_model_weights(model_dense, "../InitWeightsDense")
load_model_weights(model_convDense, "../InitWeightsConvDense")
# Out:
# No weights found for layer 0.
# Loaded weights for layer 1 from ../InitWeightsDense\layer_number_1.npz
# Loaded weights for layer 0 from ../InitWeightsConvDense\layer_number_0.npz
# No weights found for layer 1.
# Loaded weights for layer 2 from ../InitWeightsConvDense\layer_number_2.npz

# %%
class SaveWeightsCallback(callbacks.Callback):
    def __init__(self, save_dir):
        super(SaveWeightsCallback, self).__init__()
        self.save_dir = save_dir

    def on_epoch_end(self, epoch, logs=None):
        epoch_dir = os.path.join(self.save_dir, f"AfterEpoch{epoch + 1}")
        if not os.path.exists(epoch_dir):
            os.makedirs(epoch_dir)
        
        for layer_num, layer in enumerate(self.model.layers):
            if layer.weights:  # Only save weights for layers that have weights
                file_path = os.path.join(epoch_dir, f"Layer_{layer_num}.npz")
                weights = layer.get_weights()
                np.savez(file_path, *weights)
                print(f"Saved weights for layer {layer_num} to {file_path}")

# %%
save_dir_dense = "results/One_WeightsDense"
save_dir_convDense = "results/One_WeightsConvDense"
save_weights_callback_dense = SaveWeightsCallback(save_dir_dense)
save_weights_callback_convDense = SaveWeightsCallback(save_dir_convDense)

# %%
history_dense = model_dense.fit(
    x_train, y_train,
    epochs=15,  
    callbacks=[save_weights_callback_dense]
)
history_convDense = model_convDense.fit(
    x_train, y_train,
    epochs=15,  
    callbacks=[save_weights_callback_convDense]
)
# Out:
# Epoch 1/15
# 308/338 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.9249 - loss: 3.6775Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch1\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 860us/step - accuracy: 0.9276 - loss: 3.5075
# Epoch 2/15
# 274/338 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9729 - loss: 0.7242Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch2\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9729 - loss: 0.7280
# Epoch 3/15
# 286/338 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.9817 - loss: 0.4608Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch3\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9812 - loss: 0.4753
# Epoch 4/15
# 303/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9806 - loss: 0.5312Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch4\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9805 - loss: 0.5309
# Epoch 5/15
# 329/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9801 - loss: 0.4572Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch5\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9800 - loss: 0.4583
# Epoch 6/15
# 309/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9835 - loss: 0.3697Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch6\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9831 - loss: 0.3822
# Epoch 7/15
# 328/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9828 - loss: 0.3865Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch7\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9828 - loss: 0.3882
# Epoch 8/15
# 313/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9817 - loss: 0.3735Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch8\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9817 - loss: 0.3748
# Epoch 9/15
# 302/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9825 - loss: 0.3180  Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch9\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9825 - loss: 0.3256
# Epoch 10/15
# 327/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9848 - loss: 0.2842Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch10\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9848 - loss: 0.2861
# Epoch 11/15
# 325/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9817 - loss: 0.3484Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch11\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9817 - loss: 0.3496
# Epoch 12/15
# 307/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9822 - loss: 0.3054Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch12\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9822 - loss: 0.3078
# Epoch 13/15
# 320/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.3470Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch13\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.3461
# Epoch 14/15
# 316/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9833 - loss: 0.2869Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch14\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9833 - loss: 0.2894
# Epoch 15/15
# 326/338 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.9831 - loss: 0.3882Saved weights for layer 1 to results/One_WeightsDense\AfterEpoch15\Layer_1.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.9831 - loss: 0.3874
# Epoch 1/15
# 315/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9198 - loss: 4.2581Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch1\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch1\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9222 - loss: 4.1018
# Epoch 2/15
# 329/338 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.6599Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch2\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch2\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9744 - loss: 0.6605
# Epoch 3/15
# 324/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9755 - loss: 0.4584Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch3\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch3\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9755 - loss: 0.4561
# Epoch 4/15
# 308/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9812 - loss: 0.2662Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch4\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch4\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9811 - loss: 0.2693
# Epoch 5/15
# 331/338 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9785 - loss: 0.2360Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch5\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch5\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9785 - loss: 0.2359
# Epoch 6/15
# 295/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.1985Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch6\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch6\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9787 - loss: 0.1988
# Epoch 7/15
# 334/338 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9804 - loss: 0.1651Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch7\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch7\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9804 - loss: 0.1650
# Epoch 8/15
# 332/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.1497Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch8\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch8\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9782 - loss: 0.1495
# Epoch 9/15
# 328/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.1269Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch9\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch9\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9798 - loss: 0.1265
# Epoch 10/15
# 331/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9827 - loss: 0.1007Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch10\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch10\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9827 - loss: 0.1008
# Epoch 11/15
# 332/338 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9839 - loss: 0.0745Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch11\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch11\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9838 - loss: 0.0750
# Epoch 12/15
# 327/338 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9843 - loss: 0.0756Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch12\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch12\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9843 - loss: 0.0758
# Epoch 13/15
# 318/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9866 - loss: 0.0586Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch13\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch13\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9864 - loss: 0.0592
# Epoch 14/15
# 309/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9826 - loss: 0.0695Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch14\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch14\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9826 - loss: 0.0693
# Epoch 15/15
# 318/338 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9849 - loss: 0.0582Saved weights for layer 0 to results/One_WeightsConvDense\AfterEpoch15\Layer_0.npz
# Saved weights for layer 2 to results/One_WeightsConvDense\AfterEpoch15\Layer_2.npz
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.0582

# %%
test_loss, test_acc = model_dense.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

test_loss, test_acc = model_convDense.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9801 - loss: 0.4967
# Test accuracy: 0.9808642268180847
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9718 - loss: 0.1401
# Test accuracy: 0.9740740656852722

# %%
dense_history_dict = history_dense.history
conv_dense_history_dict = history_convDense.history
dense_accuracy = dense_history_dict['accuracy']
conv_dense_accuracy = conv_dense_history_dict['accuracy']
dense_loss = dense_history_dict['loss']
conv_dense_loss = conv_dense_history_dict['loss']

epochs = range(1, len(dense_accuracy) + 1)

# accuracy
plt.figure(figsize=(8, 6))  
plt.plot(epochs, dense_accuracy, 'bo-', label='Dense Accuracy', markersize=8)
plt.plot(epochs, conv_dense_accuracy, 'go-', label='ConvDense Accuracy', markersize=8)
plt.title('Accuracy over Epochs', fontsize=18)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(ticks=epochs)
plt.savefig("results/one_accuracy_plot.png", bbox_inches='tight', dpi=1000 )
plt.show()
plt.close()

# loss
plt.figure(figsize=(8, 6))  # Larger figure for better clarity
plt.plot(epochs, dense_loss, 'bo-', label='Dense Loss', markersize=8)
plt.plot(epochs, conv_dense_loss, 'go-', label='ConvDense Loss', markersize=8)
plt.title('Loss over Epochs', fontsize=18)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.xticks(ticks=epochs)
plt.savefig("results/one_loss_plot.png", bbox_inches='tight', dpi=1000)
plt.show()
plt.close()

# %%
def plot_kernel(kernel, title):
    plt.figure(figsize=(6, 6))
    # Extract the 2D slice of the kernel weights
    kernel_2d = kernel.reshape(3,3) # Assumes single channel filter
    sns.heatmap(kernel_2d, annot=True, cmap="coolwarm", cbar=True)
    plt.title(title)
    plt.show()
final_kernel = model_convDense.layers[0].get_weights()[0]
plot_kernel(final_kernel, 'Trained Weights of Kernel One')
